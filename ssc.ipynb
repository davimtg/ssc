# %%
import pandas as pd

df = pd.read_csv('./data/features_not_infected_leve_BALF_SRR11181957.tsv', sep='\t')

# %%
df.shape
# Out:
# (20515, 535)

# %%
df.head()
# Out:
#                      AAACCTGGTCTAGTGT.1  AAACGGGAGATCGGGT.1  \
# human----AL627309.1                 0.0                 0.0
# human----AL627309.3                 0.0                 0.0
# human----AL627309.5                 0.0                 0.0
# human----LINC01409                  0.0                 0.0
# human----LINC01128                  0.0                 0.0
#
#                      AAACGGGCAATCGAAA.1  AAACGGGCAGTAAGAT.1  \
# human----AL627309.1                 0.0                 0.0
# human----AL627309.3                 0.0                 0.0
# human----AL627309.5                 0.0                 0.0
# human----LINC01409                  0.0                 0.0
# human----LINC01128                  0.0                 0.0
#
#                      AAACGGGTCGAATGCT.1  AAACGGGTCGTATCAG.1  \
# human----AL627309.1                 0.0                 0.0
# human----AL627309.3                 0.0                 0.0
# ...

# %%
df.columns
# Out:
# Index(['AAACCTGGTCTAGTGT.1', 'AAACGGGAGATCGGGT.1', 'AAACGGGCAATCGAAA.1',
#        'AAACGGGCAGTAAGAT.1', 'AAACGGGTCGAATGCT.1', 'AAACGGGTCGTATCAG.1',
#        'AAAGCAAAGCCCAATT.1', 'AAAGCAACAGCATGAG.1', 'AAAGCAATCCGGGTGT.1',
#        'AAAGTAGAGGTTACCT.1',
#        ...
#        'TTGGAACGTACATGTC.1', 'TTTACTGTCTTCGGTC.1', 'TTTATGCCATGGTAGG.1',
#        'TTTCCTCCATGTCTCC.1', 'TTTCCTCTCCGCATCT.1', 'TTTGGTTGTACGACCC.1',
#        'TTTGGTTGTCCAGTAT.1', 'TTTGGTTTCACATAGC.1', 'TTTGGTTTCGCTTGTC.1',
#        'TTTGTCACAGGCAGTA.1'],
#       dtype='object', length=535)
